# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from statistics import mean

# %%
df=load_breast_cancer()
features=pd.DataFrame(df.data,columns=df.feature_names)
target=pd.Series(df.target)

# %%
'''xscaler=MinMaxScaler()
X=xscaler.fit_transform(np.array(features))
'''
X=np.array(features)
y=np.array(target)

# %%
err=[]
for i in range(10):
    xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=0.2,random_state=i*5)
    model=LogisticRegression()
    model.fit(xtrain,ytrain)
    ypred=model.predict(xtest)
    err.append(accuracy_score(ypred,ytest))
mean(err)
# Out:
# C:\Users\Bhagwan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\Bhagwan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\Bhagwan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\Bhagwan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\Bhagwan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\Bhagwan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\Bhagwan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\Bhagwan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\Bhagwan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\Bhagwan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.9359649122807018

# %%
from yellowbrick.features import Rank1D
visualizer = Rank1D(algorithm='shapiro', features=df.feature_names)

visualizer.fit(X, y)           # Fit the data to the visualizer
visualizer.transform(X)        # Transform the data
visualizer.show()              # Finalize and render the figure

# %%
arr=visualizer.ranks_

# %%
score=[]
for i in range(len(arr)):
    score.append([arr[i],df.feature_names[i]])
score.sort()
score
# Out:
# [[0.563820481300354, 'area error'],
#  [0.6720700263977051, 'concavity error'],
#  [0.69507896900177, 'fractal dimension error'],
#  [0.7181644439697266, 'perimeter error'],
#  [0.7455540895462036, 'radius error'],
#  [0.8160704970359802, 'worst area'],
#  [0.828387439250946, 'symmetry error'],
#  [0.8368780612945557, 'compactness error'],
#  [0.8384096622467041, 'smoothness error'],
#  [0.8584018349647522, 'mean area'],
#  [0.8668309450149536, 'mean concavity'],
#  [0.8895459175109863, 'worst fractal dimension'],
#  [0.8910645842552185, 'worst compactness'],
#  [0.8916499018669128, 'mean concave points'],
#  [0.8961676359176636, 'texture error'],
#  [0.9125850796699524, 'worst perimeter'],
#  [0.9134925603866577, 'worst radius'],
#  [0.9161444306373596, 'worst symmetry'],
#  [0.9169784784317017, 'mean compactness'],
#  [0.9175271391868591, 'worst concavity'],
#  [0.9197062253952026, 'concave points error'],
#  [0.9232836961746216, 'mean fractal dimension'],
#  [0.9361826181411743, 'mean perimeter'],
#  [0.9410696029663086, 'mean radius'],
#  [0.9648364186286926, 'worst concave points'],
#  [0.972588062286377, 'mean symmetry'],
#  [0.9767200946807861, 'mean texture'],
#  [0.9825620651245117, 'worst texture'],
#  [0.987487256526947, 'mean smoothness'],
#  [0.9886201024055481, 'worst smoothness']]

# %%
drop=[]
for i in range(11):
    drop.append(score[i][1])
print(drop)
# Out:
# ['area error', 'concavity error', 'fractal dimension error', 'perimeter error', 'radius error', 'worst area', 'symmetry error', 'compactness error', 'smoothness error', 'mean area', 'mean concavity']

# %%
from yellowbrick.features import RadViz
visualizer = RadViz()

visualizer.fit(X, y)           # Fit the data to the visualizer
visualizer.transform(X)        # Transform the data
visualizer.show()              # Finalize and render the figure

# %%
from yellowbrick.features import ParallelCoordinates
visualizer = ParallelCoordinates()

visualizer.fit(X, y)           # Fit the data to the visualizer
visualizer.transform(X)        # Transform the data
visualizer.show()              # Finalize and render the figure

# %%
from yellowbrick.features import PCA
visualizer = PCA(projection=3)

visualizer.fit_transform(X, y)           # Fit the data to the visualizer
#visualizer.transform(X)        # Transform the data
visualizer.show()              # Finalize and render the figure

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9063a9f0e032> in <module>
# ----> 1 y
#
# NameError: name 'y' is not defined
